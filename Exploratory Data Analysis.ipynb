# %% [markdown]
# Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('hr_employee_churn_data.csv')

# %%
df.head()
# Out:
#    empid  satisfaction_level  last_evaluation  number_project  \
# 0      1                0.38             0.53               2
# 1      2                0.80             0.86               5
# 2      3                0.11             0.88               7
# 3      4                0.72             0.87               5
# 4      5                0.37             0.52               2
#
#    average_montly_hours  time_spend_company  Work_accident  \
# 0                   157                   3              0
# 1                   262                   6              0
# 2                   272                   4              0
# 3                   223                   5              0
# 4                   159                   3              0
#
#    promotion_last_5years  salary  left
# 0                      0     low     1
# 1                      0  medium     1
# 2                      0  medium     1
# 3                      0     low     1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   empid                  14999 non-null  int64
#  1   satisfaction_level     14997 non-null  float64
#  2   last_evaluation        14999 non-null  float64
#  3   number_project         14999 non-null  int64
#  4   average_montly_hours   14999 non-null  int64
#  5   time_spend_company     14999 non-null  int64
#  6   Work_accident          14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   salary                 14999 non-null  object
#  9   left                   14999 non-null  int64
# dtypes: float64(2), int64(7), object(1)
# memory usage: 1.1+ MB

# %%
#number of rows and columns
df.shape
# Out:
# (14999, 10)

# %%
df.describe()
# Out:
#               empid  satisfaction_level  last_evaluation  number_project  \
# count  14999.000000        14997.000000     14999.000000    14999.000000
# mean    7500.000000            0.612863         0.716102        3.803054
# std     4329.982679            0.248634         0.171169        1.232592
# min        1.000000            0.090000         0.360000        2.000000
# 25%     3750.500000            0.440000         0.560000        3.000000
# 50%     7500.000000            0.640000         0.720000        4.000000
# 75%    11249.500000            0.820000         0.870000        5.000000
# max    14999.000000            1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident  \
# count          14999.000000        14999.000000   14999.000000
# mean             201.050337            3.498233       0.144610
# std               49.943099            1.460136       0.351719
# ...

# %%
df['Work_accident'].unique()
# Out:
# array([0, 1])

# %%
df['promotion_last_5years'].unique()
# Out:
# array([0, 1])

# %%
sns.countplot(x='left', data=df)
plt.show()
#take away: in training set, less people left the company than stayed, it seems there is a imbalance in the dataset

# %%
sns.countplot(x='salary', data=df)
plt.show()

# %%
#feature 'left' split over the feature 'salary'
sns.catplot(x='left', col='salary', data=df, kind='count')
plt.show()
#take away: people with high salary are less likely to leave the company, while people with low salary are more likely to leave the company

# %%
sns.countplot(x='promotion_last_5years', data=df)
plt.show()

# %%
#fearure 'promotion_last_5years' split over the feature 'left'
sns.catplot(x='left', col='promotion_last_5years', data=df, kind='count')
plt.show()

# %%
sns.countplot(x='Work_accident', data=df)
plt.show()

# %%
sns.catplot(x='left', col='Work_accident', data=df, kind='count')
plt.show()
#take away: not much important

# %%
#satisfaction level
sns.distplot(df['satisfaction_level'])
# Out:
# /var/folders/s0/smpstk6x2kd_pppyythh4r300000gn/T/ipykernel_19143/3603395895.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['satisfaction_level'])
# <Axes: xlabel='satisfaction_level', ylabel='Density'>

# %%
sns.boxplot(x='left', y='satisfaction_level', data=df)
# Out:
# <Axes: xlabel='left', ylabel='satisfaction_level'>

# %%
sns.distplot(df['number_project'])
# Out:
# /var/folders/s0/smpstk6x2kd_pppyythh4r300000gn/T/ipykernel_19143/487619780.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['number_project'])
# <Axes: xlabel='number_project', ylabel='Density'>

# %%
sns.boxplot(x='left', y='number_project', data=df)
# Out:
# <Axes: xlabel='left', ylabel='number_project'>

# %%
sns.distplot(df['last_evaluation'])
# Out:
# /var/folders/s0/smpstk6x2kd_pppyythh4r300000gn/T/ipykernel_19143/3558093561.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['last_evaluation'])
# <Axes: xlabel='last_evaluation', ylabel='Density'>

# %%
sns.distplot(df['average_montly_hours'])
# Out:
# /var/folders/s0/smpstk6x2kd_pppyythh4r300000gn/T/ipykernel_19143/4008227430.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['average_montly_hours'])
# <Axes: xlabel='average_montly_hours', ylabel='Density'>

# %%
sns.boxplot(x='left', y='average_montly_hours', data=df)
# Out:
# <Axes: xlabel='left', ylabel='average_montly_hours'>

# %%
sns.boxplot(x='left', y='last_evaluation', data=df)
# Out:
# <Axes: xlabel='left', ylabel='last_evaluation'>

# %%
sns.boxplot(x='left', y='time_spend_company', data=df)
# Out:
# <Axes: xlabel='left', ylabel='time_spend_company'>

# %%
#checking for correlation

numeric_df = df.select_dtypes(include=['number'])

corr_matrix = numeric_df.corr()
fig = plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
df2 = df.copy()

# %%
df2.drop()
